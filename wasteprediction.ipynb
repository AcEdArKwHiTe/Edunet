# %% [markdown]
# <a href="https://colab.research.google.com/github/AcEdArKwHiTe/Edunet/blob/main/wasteprediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib

# %%
data = pd.read_csv('waste_classification_dataset_500.csv')

# %%
print(data.head())
# Out:
#    Weight(g)  Moisture(%)  Hardness  Magnetic  Biodegradable WasteType
# 0         30            3         1         0              0   Plastic
# 1        190            2         8         1              0     Metal
# 2         78           78         1         0              1   Organic
# 3         79            2         7         0              0     Glass
# 4         48            3         3         0              0     Paper

# %%
x = data.drop("WasteType", axis = 1)
y = data["WasteType"]

# %%
encoder = LabelEncoder()
y = encoder.fit_transform(y)
y
# Out:
# array([4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1,
#        2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0,
#        3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4,
#        1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2,
#        0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3,
#        4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1,
#        2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0,
#        3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4,
#        1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2,
#        0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3,
#        4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1,
#        2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0,
#        3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4,
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
lr = LogisticRegression(max_iter= 4700)
lr.fit(X_train, y_train)
lr_pred = lr.predict(X_test)
lr_pred
# Out:
# array([1, 0, 3, 4, 3, 3, 2, 3, 0, 3, 3, 3, 1, 3, 1, 0, 4, 4, 1, 0, 4, 1,
#        4, 1, 1, 1, 2, 1, 1, 3, 4, 1, 4, 0, 2, 0, 3, 4, 0, 0, 3, 0, 4, 4,
#        0, 2, 4, 1, 4, 2, 2, 2, 1, 4, 0, 4, 0, 0, 3, 3, 4, 2, 0, 3, 4, 3,
#        1, 1, 0, 1, 2, 1, 2, 4, 2, 3, 0, 0, 4, 4, 3, 2, 2, 2, 1, 4, 4, 3,
#        2, 0, 1, 2, 2, 0, 1, 2, 1, 4, 0, 4])

# %%
print("Logistic Reegression Accuracy")
print(accuracy_score(y_test, lr_pred))
print("\n Classification report")
print(classification_report(y_test, lr_pred))
print("\n Confusion Matrix")
print(confusion_matrix(y_test, lr_pred))
# Out:
# Logistic Reegression Accuracy
# 0.92
#
#  Classification report
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87        19
#            1       1.00      1.00      1.00        21
#            2       1.00      1.00      1.00        18
#            3       0.83      0.75      0.79        20
#            4       0.91      0.95      0.93        22
#
#     accuracy                           0.92       100
#    macro avg       0.92      0.92      0.92       100
# weighted avg       0.92      0.92      0.92       100
#
#
#  Confusion Matrix
# [[17  0  0  2  0]
#  [ 0 21  0  0  0]
#  [ 0  0 18  0  0]
#  [ 3  0  0 15  2]
#  [ 0  0  0  1 21]]

# %%
joblib.dump(lr, 'Waste_type_classification_LRModel.pkl') #Logistics regression model
# Out:
# ['Waste_type_classification_LRModel.pkl']

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(max_depth= 10)
dt.fit(X_train, y_train)
dt_pred = dt.predict(X_test)
dt_pred
# Out:
# array([1, 0, 0, 4, 3, 3, 2, 3, 0, 3, 3, 3, 1, 3, 1, 0, 4, 4, 1, 0, 4, 1,
#        4, 1, 1, 1, 2, 1, 1, 3, 4, 1, 4, 0, 2, 0, 3, 4, 3, 0, 3, 0, 4, 4,
#        0, 2, 4, 1, 4, 2, 2, 2, 1, 4, 0, 4, 0, 0, 3, 0, 4, 2, 0, 0, 3, 3,
#        1, 1, 0, 1, 2, 1, 2, 4, 2, 3, 0, 3, 4, 4, 3, 2, 2, 2, 1, 4, 4, 3,
#        2, 0, 1, 2, 2, 0, 1, 2, 1, 4, 0, 4])

# %%
print("Decision Tree Accuracy")
print(accuracy_score(y_test, dt_pred))
print("\n Classification report")
print(classification_report(y_test, dt_pred))
print("\n Confusion Matrix")
print(confusion_matrix(y_test, dt_pred))
# Out:
# Decision Tree Accuracy
# 0.95
#
#  Classification report
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.92        19
#            1       1.00      1.00      1.00        21
#            2       1.00      1.00      1.00        18
#            3       0.86      0.90      0.88        20
#            4       0.95      0.95      0.95        22
#
#     accuracy                           0.95       100
#    macro avg       0.95      0.95      0.95       100
# weighted avg       0.95      0.95      0.95       100
#
#
#  Confusion Matrix
# [[17  0  0  2  0]
#  [ 0 21  0  0  0]
#  [ 0  0 18  0  0]
#  [ 1  0  0 18  1]
#  [ 0  0  0  1 21]]

# %%
joblib.dump(lr, 'Waste_type_classification_DTModel.pkl') #Descision tree model
# Out:
# ['Waste_type_classification_DTModel.pkl']
